# %% [markdown]
# # Day 1, part 1

# %%
import numpy as np

# %%
test = '''1000
2000
3000

4000

5000
6000

7000
8000
9000

10000'''

# %%
type(test)
# Out:
# str

# %%
test = test.split('\n\n')

# %%
for group in test:
    print(np.array(list(map(int, group.split('\n')))).sum())
# Out:
# 6000
# 4000
# 11000
# 24000
# 10000

# %%
with open('input.txt') as f:
    data = f.readlines()

# %%
"".join(data)
# Out:
# '5800\n2273\n1315\n5801\n6352\n2649\n4140\n2115\n5298\n4441\n4428\n3773\n1076\n\n8063\n10386\n5705\n8397\n1084\n7661\n\n3661\n5756\n3231\n5162\n4930\n4675\n1113\n6795\n6415\n1144\n2900\n5147\n2966\n\n35187\n\n12434\n2038\n12435\n8757\n6976\n4532\n\n4642\n4431\n5126\n4672\n1724\n3012\n\n3801\n6564\n5401\n3913\n3090\n1484\n6227\n1283\n2501\n4601\n5860\n7036\n\n19257\n31867\n\n4292\n4518\n1298\n13147\n7463\n\n6784\n1065\n4015\n3154\n6429\n5067\n6535\n5731\n1270\n5870\n4934\n2800\n\n5227\n6294\n6733\n5177\n2773\n6553\n3219\n1446\n7005\n6036\n6872\n\n1721\n4408\n5577\n2799\n2257\n3149\n2389\n3713\n5588\n2324\n4595\n6018\n4926\n\n1233\n4799\n3380\n1975\n1924\n1578\n2338\n1546\n3708\n4020\n5872\n2519\n5334\n4416\n\n18103\n1692\n10497\n6786\n\n4837\n12315\n6510\n9221\n10023\n5698\n\n9781\n18818\n19784\n5100\n\n7596\n14668\n18708\n\n1932\n18024\n6361\n\n7302\n5163\n9039\n4774\n8726\n6538\n2054\n7238\n4233\n\n3375\n6049\n4925\n7129\n6075\n1262\n3836\n5878\n3292\n1316\n3924\n3530\n\n8653\n21172
# ...

# %% [markdown]
# # Part 2

# %%
np.argsort([1, 6, 7,23, 2345, 6, 3])
# Out:
# array([0, 6, 1, 5, 2, 3, 4], dtype=int64)

# %%
np.sort([234, 34,65, 3456 ,0])
# Out:
# array([   0,   34,   65,  234, 3456])
